# %% [markdown]
# <a href="https://colab.research.google.com/github/midhunkrishnam/Machine-Learning-Algoritnms/blob/main/2_RegressionML__Salary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
df=pd.read_csv("/content/Salary.csv")
df
# Out:
#     YearsExperience  Salary
# 0               1.1   39343
# 1               1.3   46205
# 2               1.5   37731
# 3               2.0   43525
# 4               2.2   39891
# 5               2.9   56642
# 6               3.0   60150
# 7               3.2   54445
# 8               3.2   64445
# 9               3.7   57189
# 10              3.9   63218
# 11              4.0   55794
# 12              4.0   56957
# 13              4.1   57081
# 14              4.5   61111
# 15              4.9   67938
# 16              5.1   66029
# 17              5.3   83088
# 18              5.9   81363
# 19              6.0   93940
# 20              6.8   91738
# 21              7.1   98273
# 22              7.9  101302
# 23              8.2  113812
# 24              8.7  109431
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872
# 30             11.2  127345
# 31             11.5  126756
# ...

# %%
print(df.columns)
# Out:
# Index(['YearsExperience', 'Salary'], dtype='object')

# %%
df.head()
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891

# %%
df.tail()
# Out:
#     YearsExperience  Salary
# 30             11.2  127345
# 31             11.5  126756
# 32             12.3  128765
# 33             12.9  135675
# 34             13.5  139465

# %%
print(df.isna().sum())
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
x=df.iloc[:,:-1].values
y=df.iloc[:,-1].values

x
y
# Out:
# array([ 39343,  46205,  37731,  43525,  39891,  56642,  60150,  54445,
#         64445,  57189,  63218,  55794,  56957,  57081,  61111,  67938,
#         66029,  83088,  81363,  93940,  91738,  98273, 101302, 113812,
#        109431, 105582, 116969, 112635, 122391, 121872, 127345, 126756,
#        128765, 135675, 139465])

# %%
# x=df['YearsExperience']
# y=df['Salary']

# x
# y

# %%
plt.xlabel("year of exp")
plt.ylabel("salary")
plt.title("experiance vs salary")
plt.scatter(x,y)

plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=1)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
y_pred
# Out:
# array([ 67631.40503486,  80836.12861418,  45623.53240266, 120450.29935213,
#        141577.85707904, 118689.66954156,  97562.11181465, 112527.46520454,
#        111647.15029926, 136295.96764732,  74673.92427716])

# %%
import matplotlib.pyplot as plt
plt.scatter(x_train,y_train,color="yellow")
plt.plot(x_test,y_pred,color="green")
plt.show()

# %%
y_test
# Out:
# array([ 61111,  93940,  43525, 121872, 135675, 122391, 101302, 112635,
#        116969, 128765,  83088])

# %%
y_pred
# Out:
# array([ 67631.40503486,  80836.12861418,  45623.53240266, 120450.29935213,
#        141577.85707904, 118689.66954156,  97562.11181465, 112527.46520454,
#        111647.15029926, 136295.96764732,  74673.92427716])

# %%
s=pd.DataFrame({"actualvalue":y_test,"pedicted value":y_pred})
s
# Out:
#     actualvalue  pedicted value
# 0         61111    67631.405035
# 1         93940    80836.128614
# 2         43525    45623.532403
# 3        121872   120450.299352
# 4        135675   141577.857079
# 5        122391   118689.669542
# 6        101302    97562.111815
# 7        112635   112527.465205
# 8        116969   111647.150299
# 9        128765   136295.967647
# 10        83088    74673.924277
